# %% [markdown]
# # Matplotlib Task

# %% [markdown]
# ## Create plots using the following data.
# Создать графики,используя следующие данные

# %%
import numpy as np
a = np.arange(0,100)
b = a - 5
c = a ** 3 - b ** 2

# %% [markdown]
# ### 1. Import matplotlib.pyplot and set %matplotlib inline

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# ### 2. a. Create a figure object.
# Создать объект фигуру
# ### b. Add axes to the figure object passing [0, 0, 1, 1] list as a parameter.
# Добавить оси в список передачи объекта фигуры в качестве параметра
# ### c. Create a plot with a as x axis data and b as y axis data
# Создать график с данными оси х и данными оси у
# ### d. Add labels to the plot like on the plot below
# Добавить менки к графиу как на графике ниже

# %%
#1.Создать объект фигуру
figure = plt.figure()
#2.добавим оси координат ([левый, нижний,ширина,высота])
axes = figure.add_axes([0, 0, 1, 1])
#3.Показать график(начертить)
axes.plot(a, b)
#4.Определить имя для горизонтальной оси
axes.set_xlabel('a label')
#5.Определить имя для вертикальной оси
axes.set_ylabel('b label')
#6.Определить название графика
axes.set_title('title label')
# Out:
# Text(0.5, 1.0, 'title label')

# %%
правильный ответ
# Out:
# Text(0.5, 1.0, 'title label')

# %% [markdown]
# ### 3. Create a figure object and add two axes - axes1 and axes2. Pass the following lists as parameters - [0, 0, 1, 1] to axes1 and [0.2, 0.5, 0.2, 0.3] to axes2
# Создайте объект-фигуру и добавьте две оси Axes1 и Axes2.Передайте следующие списки в качестве параметров[0,0,1,1] в
# axes1[0.2,0.5,0.2,0.3] в axes2

# %%
#Создадим еще одну рамку
figure = plt.figure()
#ось координат для первой рамки
axes1 = figure.add_axes([0, 0, 1, 1])
#ось координат для второй рамки
axes2 = figure.add_axes([0.2, 0.5, 0.2, 0.3])

# %%
правильный ответ

# %% [markdown]
# ### 4. Create plots with a as x axis data and b as y axis data on axes1 and with b as x axis data and c as y axis data on axes2 for the previos figure object and show the plot by calling figure variable
# Создать графики а с данными оси х и b с данными оси у на оси1 и с b как даннными оси и с как данными оси у на осях 2 для предыдущего объекта фигуры и показать график,вызвав переменную фигуры

# %%
# figure = plt.figure()
# axes1 = figure.add_axes([0, 0, 1, 1])
# axes2 = figure.add_axes([0.2, 0.5, 0.2, 0.3])

#вставляем в рамки графики 
axes1.plot(a, b)
axes2.plot(b, c)
figure

# %% [markdown]
# ### 5. a. Create a figure object and add two axes - axes1 and axes2. Pass the following lists as parameters - [0, 0, 1, 1] to axes1 and [0.2, 0.5, 0.3, 0.4] to axes2
# Создать объект-фигуру и добавить две оси- ось1 и ось2.Передайте следующие списки в качестве параметров[0,0,1,1] осям1 и [0.2,0.5,0.3,0.4] осям2
#
# ### b. Create plots using a, b, c arrays to match the image below. Add limits to the plots - x limit equals (20, 60) and y limit equals (10, 70) for axes1 and x limit equals (20, 60) and y limit equals (10000, 70000) for axes2
# Создать графики используя массивы а,b,c чтобы они соответствовали изображению ниже.Добавьте пределы к plots х(20,60) и у(10,70) для осей1, а предел х(20,60) и у(10000,70000)

# %%
#a.Создать объект-фигуру и добавить две оси- ось1 и ось2.Передайте следующие списки
#в качестве параметров[0,0,1,1] осям1 и [0.2,0.5,0.3,0.4] осям2
figure = plt.figure()
axes1 = figure.add_axes([0, 0, 1, 1])
axes2 = figure.add_axes([0.2, 0.5, 0.3, 0.4])

#b.Создать графики используя массивы а,b,c чтобы они соответствовали изображению ниже.
#вставляем в рамки графики 

axes1.plot(a, b)
axes1.set_xlabel('a array')
axes1.set_ylabel('b array')
axes1.set_title('Outer plot')
#Добавьте пределы к plots х(20,60) и у(10,70) для осей1 
axes1.set_xlim([20, 60])
axes1.set_ylim([10, 70])

axes2.plot(a, c)
axes2.set_xlabel('a array ')
axes2.set_ylabel('c array ')
axes2.set_title('Inner plot')
#Добавьте пределы к plots х(20,60) и у(10000,70000) для осей2
axes2.set_xlim([20, 60])
axes2.set_ylim([10000, 70000])
# Out:
# (10000.0, 70000.0)

# %%
# Out:
# (10000, 70000)

# %% [markdown]
# ### 6. a. Create a figure object with 2 axes in 1 row with the help of subplots() method
# Создать объект фигр с двумя осями координат в одной строке при помощи субплотс метода
# ### b. Resize both axes - set 11 inches to width and 3 inches to height
# Изменить размер для обоих систем координат
# ### c. Create the plot on the first axes with c as x axis data and a as y axis data
# Создайте график для первых осей с для х и а для у
# ### d. Create the plot on the second axes with c as x axis data and b as y axis data
# Создайте график для вторых осей с для х и b для у
# ### e. Change the appearance of plot lines somehow. Play with colors, width and styles
# Изменить внешний вид линий графика

# %%
#a.Создать объект фигр с двумя осями координат в одной строке при помощи субплотс метода
figure, axes = plt.subplots(nrows=1, ncols=2)
#b.Изменить размер для обоих систем координат
figure, axes = plt.subplots(nrows=1, ncols=2, figsize=(11, 3))
#c.Создайте график для первых осей с для х и а для у
#axes[0].plot(c, a)
#d.Создайте график для вторых осей с для х и b для у
#axes[1].plot(c, b)
#e.Изменить внешний вид линий графика
axes[0].plot(c, a, color='purple', ls='--', lw=2)
axes[1].plot(c, b, color='orange', ls=':', lw=5)
