# %%
отец = 1933
мать = 1945
я    = 1979

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
figure = plt.figure()
axes1 = figure.add_axes([1, 9, 3, 3])
axes2 = figure.add_axes([1, 9, 4, 5])
