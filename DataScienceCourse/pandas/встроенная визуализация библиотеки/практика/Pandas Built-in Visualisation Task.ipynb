# %% [markdown]
# ### 1. Import pyplot from matplotlib

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# ### 2. Import pandas for csv file reading

# %%
import pandas as pd

# %% [markdown]
# ### 3. Write the code which allows to show plots in jupiter notebook

# %%
# %matplotlib inline

# %% [markdown]
# ### 4. Create a variable and read data from dataframe3 csv file in it
# Создайте переменную и считайте в нее данные из csv-файла dataframe3

# %%
df = pd.read_csv('dataframe3')
df
# Out:
#             a         b         c         d
# 0    0.336232  0.327011  0.001020  0.401402
# 1    0.980265  0.831837  0.332288  0.036487
# 2    0.480383  0.686839  0.000735  0.346378
# 3    0.702106  0.307142  0.368608  0.674687
# 4    0.876602  0.131448  0.173931  0.321231
# ..        ...       ...       ...       ...
# 495  0.728304  0.226122  0.077835  0.131961
# 496  0.324330  0.217201  0.937302  0.394114
# 497  0.118038  0.264734  0.629208  0.824062
# 498  0.223021  0.660209  0.871373  0.438638
# 499  0.466173  0.373000  0.117391  0.239312
#
# [500 rows x 4 columns]

# %% [markdown]
# ### 5. Show first 10 rows from the dataset

# %%
df.head(10)
# Out:
#           a         b         c         d
# 0  0.336232  0.327011  0.001020  0.401402
# 1  0.980265  0.831837  0.332288  0.036487
# 2  0.480383  0.686839  0.000735  0.346378
# 3  0.702106  0.307142  0.368608  0.674687
# 4  0.876602  0.131448  0.173931  0.321231
# 5  0.307933  0.632689  0.704017  0.313622
# 6  0.166324  0.269333  0.608769  0.834423
# 7  0.074041  0.966440  0.067797  0.109448
# 8  0.373839  0.723887  0.723210  0.226936
# 9  0.427383  0.213301  0.049020  0.283794

# %%
# Out:
#           a         b         c         d
# 0  0.336232  0.327011  0.001020  0.401402
# 1  0.980265  0.831837  0.332288  0.036487
# 2  0.480383  0.686839  0.000735  0.346378
# 3  0.702106  0.307142  0.368608  0.674687
# 4  0.876602  0.131448  0.173931  0.321231
# 5  0.307933  0.632689  0.704017  0.313622
# 6  0.166324  0.269333  0.608769  0.834423
# 7  0.074041  0.966440  0.067797  0.109448
# 8  0.373839  0.723887  0.723210  0.226936
# 9  0.427383  0.213301  0.049020  0.283794

# %% [markdown]
# ### 6. Try to recreate the plot with same color and size of the points, and also with the same figure size as on image below. This is the scatter plot of b vs a. You may need to refresh your matplotlib knowledge
# Попробуйте воссоздать график с тем же цветом и размером точек, а также с тем же размером фигуры, что и на изображении ниже. Это точечный график b против a. Возможно, вам потребуется обновить свои знания matplotlib

# %%
#s-размер точек
df.plot.scatter(x='a', y='b', color='green', s=70, figsize=(15, 4))
# Out:
# <AxesSubplot:xlabel='a', ylabel='b'>

# %% [markdown]
# ### 7. Try to recreate a histogram of the 'b' column

# %%
df['b'].plot.hist()
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %% [markdown]
# ### 8. Create a boxplot comparing the b and c columns.
# Создайте прямоугольную диаграмму, сравнивая столбцы b и c

# %%
df[['b', 'c']].plot.box()
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### 9. Create a kde plot of the c column
# Создайте график kde столбца c

# %%
df['c'].plot.kde()
# Out:
# <AxesSubplot:ylabel='Density'>

# %% [markdown]
# ### 10. Create an area plot of all the columns for just the rows up to 20. (hint: use .iloc).
# Создайте диаграмму площади всех столбцов только для строк до 20. (подсказка: используйте .iloc)

# %%
#alpha-прозрачность
df.iloc[:20].plot.area(alpha=0.3)
# Out:
# <AxesSubplot:>
