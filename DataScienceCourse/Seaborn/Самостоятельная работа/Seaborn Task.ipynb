# %% [markdown]
# ### 1. Import seaborn

# %%
import seaborn as sns

# %% [markdown]
# ### 2. Import pyplot from matplotlib

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# ### 3. Import pandas for csv file reading

# %%
import pandas as pd

# %% [markdown]
# ### 4. Write the code which allows to show plots in jupiter notebook
# Напишите код, который позволяет отображать графики в записной книжке юпитера

# %%
# %matplotlib inline

# %% [markdown]
# ### 5. Create a variable and read data from csv file in it
# Создайте переменную и считайте в нее данные из csv-файла

# %%
csv_file = pd.read_csv('german_credit_data.csv')
csv_file
# Out:
#      Unnamed: 0  Age     Sex  Job Housing Saving accounts Checking account  \
# 0             0   67    male    2     own             NaN           little
# 1             1   22  female    2     own          little         moderate
# 2             2   49    male    1     own          little              NaN
# 3             3   45    male    2    free          little           little
# 4             4   53    male    2    free          little           little
# ..          ...  ...     ...  ...     ...             ...              ...
# 995         995   31  female    1     own          little              NaN
# 996         996   40    male    3     own          little           little
# 997         997   38    male    2     own          little              NaN
# 998         998   23    male    2    free          little           little
# 999         999   27    male    2     own        moderate         moderate
#
#      Credit amount  Duration              Purpose
# ...

# %% [markdown]
# ### 6. Show first 10 rows from the dataset
# Показать первые 10 строк из набора данных

# %%
csv_file.head(10)
# Out:
#    Unnamed: 0  Age     Sex  Job Housing Saving accounts Checking account  \
# 0           0   67    male    2     own             NaN           little
# 1           1   22  female    2     own          little         moderate
# 2           2   49    male    1     own          little              NaN
# 3           3   45    male    2    free          little           little
# 4           4   53    male    2    free          little           little
# 5           5   35    male    1    free             NaN              NaN
# 6           6   53    male    2     own      quite rich              NaN
# 7           7   35    male    3    rent          little         moderate
# 8           8   61    male    1     own            rich              NaN
# 9           9   28    male    3     own          little         moderate
#
#    Credit amount  Duration              Purpose
# 0           1169         6             radio/TV
# 1           5951        48             radio/TV
# ...

# %%
# Out:
#    Unnamed: 0  Age     Sex  Job Housing Saving accounts Checking account  \
# 0           0   67    male    2     own             NaN           little
# 1           1   22  female    2     own          little         moderate
# 2           2   49    male    1     own          little              NaN
# 3           3   45    male    2    free          little           little
# 4           4   53    male    2    free          little           little
# 5           5   35    male    1    free             NaN              NaN
# 6           6   53    male    2     own      quite rich              NaN
# 7           7   35    male    3    rent          little         moderate
# 8           8   61    male    1     own            rich              NaN
# 9           9   28    male    3     own          little         moderate
#
#    Credit amount  Duration              Purpose
# 0           1169         6             radio/TV
# 1           5951        48             radio/TV
# ...

# %% [markdown]
# ### 7. Try to recreate the plot from image below
# Попробуйте воссоздать сюжет по изображению ниже

# %%
sns.jointplot(x='Age', y='Credit amount', data=csv_file)

# %% [markdown]
# ### 8. Try to recreate the plot from image below
# Попробуйте воссоздать сюжет по изображению ниже

# %%
sns.histplot(csv_file['Duration'], kde=False, color='green')
# Out:
# <AxesSubplot:xlabel='Duration', ylabel='Count'>

# %% [markdown]
# ### 9. Try to recreate the plot from image below
# Попробуйте воссоздать сюжет по изображению ниже

# %%
sns.boxplot(x='Housing', y='Age', data=csv_file)
# Out:
# <AxesSubplot:xlabel='Housing', ylabel='Age'>

# %% [markdown]
# ### 10. Try to recreate the plot from image below

# %%
#sns.violinplot(x='Housing', y='Age', data=csv_file)
sns.swarmplot(x='Housing', y='Age', data=csv_file, palette='plasma')
# Out:
# C:\anaconda3\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 50.2% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\anaconda3\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 13.4% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# <AxesSubplot:xlabel='Housing', ylabel='Age'>

# %% [markdown]
# ### 11. Try to recreate the plot from image below

# %%
sns.countplot(x='Sex', data=csv_file)
# Out:
# <AxesSubplot:xlabel='Sex', ylabel='count'>

# %% [markdown]
# ### 12. Try to recreate the plot from image below

# %%
csv_file_corr = csv_file.corr()
#cmap-цвет
sns.heatmap(csv_file_corr, cmap='winter')
#заголовок
plt.title('gsd.corr()')
# Out:
# Text(0.5, 1.0, 'gsd.corr()')

# %%
# Out:
# Text(0.5, 1, 'gcd.corr()')

# %% [markdown]
# ### 13. Try to recreate the plot from image below

# %%
grid = sns.FacetGrid(data = csv_file, col='Housing')
grid.map(plt.hist, 'Credit amount')
